# %%
import pandas as pd
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time

# %% [markdown]
# # 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# ### Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos You need to find following details:
# #### A) Rank
# #### B) Name
# #### C) Artist
# #### D) Upload date
# #### E) Views

# %%
driver = webdriver.Chrome(r'C:\Users\bhanu\chromedriver.exe')
driver.maximize_window()

url = 'https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)

time.sleep(5)

# %%
rank = []
name = []
uploader = []
views = []
date = []

# %%
for i in driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr/td[1]'):
    rank .append(i.text)
for i in driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr/td[2]'):
    name .append(i.text)
for i in driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr/td[3]'):
    uploader .append(i.text)
for i in driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr/td[4]'):
    views .append(i.text)
for i in driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr/td[5]'):
    date .append(i.text)

# %%
top_vid = pd.DataFrame({'Rank':rank,'Name':name, 'Uploader':uploader, 'Views':views, 'Published_Date':date})
top_vid
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[4]
# 1    2.                                   "Despacito"[7]
# 2    3.                       "Johny Johny Yes Papa"[14]
# 3    4.                               "Shape of You"[15]
# 4    5.                                  "Bath Song"[17]
# 5    6.                              "See You Again"[18]
# 6    7.                "Phonics Song with Two Words"[23]
# 7    8.                                "Uptown Funk"[24]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[25]
# 9   10.                          "Wheels on the Bus"[26]
# 10  11.                              "Gangnam Style"[27]
# 11  12.   "Masha and the Bear – Recipe for Disaster"[32]
# 12  13.                             "Dame Tu Cosita"[33]
# 13  14.                                      "Sugar"[34]
# 14  15.                                       "Roar"[35]
# ...

# %% [markdown]
# # 2. Scrape the details team India’s international fixtures from bcci.tv. Url = https://www.bcci.tv/.
# ### You need to find following details:
# #### A) Match title (I.e. 1st ODI)
# #### B) Series
# #### C) Place
# #### D) Date
# #### E) Time
#
# Note: - From bcci.tv home page you have reach to the international fixture page through code

# %%
driver = webdriver.Chrome(r'C:\Users\bhanu\chromedriver.exe')
driver.maximize_window()

url = 'https://www.bcci.tv/'
driver.get(url)

time.sleep(5)

# %%
driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a').click()
time.sleep(5)

# %%
driver.find_element(By.XPATH,'/html/body/div[6]/button').click()
time.sleep(5)

# %%
driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div/div/div/div[2]/div[3]/div[2]/div/button').click()
time.sleep(5)

# %%
driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div/div/div/div[2]/div[3]/div[2]/div/button').click()
time.sleep(5)

# %%
driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[3]/div[2]/div/button').click()
time.sleep(3)

# %%
title = []
series = []
place = []
date = []
mat_time = []

# %%
for i in driver.find_elements(By.XPATH, '//div[@class="fixture-card-main col-lg-3 col-md-6 col-sm-12 ng-scope"]/div/div/h5[2]/span'):
    series.append(i.text)
for i in driver.find_elements(By.XPATH, '//div[@class="fix-place ng-binding ng-scope"]/span[1]'):
    title.append(i.text.split('-')[0])
for i in driver.find_elements(By.XPATH, '//div[@class="fix-place ng-binding ng-scope"]'):
    place.append(i.text.split('-')[1])
for i in driver.find_elements(By.XPATH, '//div[@class="fixture-card-top"]/div/div[1]/h5'):
    date.append(i.text)
for i in driver.find_elements(By.XPATH, '//div[@class="fixture-card-top"]/div/div[2]/h5'):
    mat_time.append(i.text)

# %%
df = pd.DataFrame({'TitleOfMatch':title,'Series':series, 'Place':place, 'Date':date, 'Time':mat_time})
df
# Out:
#    TitleOfMatch                                        Series  \
# 0      3rd ODI    INDIA TOUR OF BANGLADESH ODI SERIES 2022-23
# 1     2nd T20I             AUSTRALIA WOMEN TOUR OF INDIA 2022
# 2     1st Test   INDIA TOUR OF BANGLADESH TEST SERIES 2022-23
# 3     3rd T20I             AUSTRALIA WOMEN TOUR OF INDIA 2022
# 4     4th T20I             AUSTRALIA WOMEN TOUR OF INDIA 2022
# 5     5th T20I             AUSTRALIA WOMEN TOUR OF INDIA 2022
# 6     2nd Test   INDIA TOUR OF BANGLADESH TEST SERIES 2022-23
# 7     1st T20I     SRI LANKA TOUR OF INDIA T20 SERIES 2022-23
# 8     2nd T20I     SRI LANKA TOUR OF INDIA T20 SERIES 2022-23
# 9     3rd T20I     SRI LANKA TOUR OF INDIA T20 SERIES 2022-23
# 10     1st ODI     SRI LANKA TOUR OF INDIA ODI SERIES 2022-23
# 11     2nd ODI     SRI LANKA TOUR OF INDIA ODI SERIES 2022-23
# 12     3rd ODI     SRI LANKA TOUR OF INDIA ODI SERIES 2022-23
# 13     1st ODI   NEW ZEALAND TOUR OF INDIA ODI SERIES 2022-23
# ...

# %% [markdown]
# # 3. Scrape the details of selenium exception from guru99.com. Url = https://www.guru99.com/
# ### You need to find following details:
# #### A) Name
# #### B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
driver = webdriver.Chrome(r'C:\Users\bhanu\chromedriver.exe')
driver.maximize_window()

url = 'https://www.guru99.com/'
driver.get(url)

time.sleep(5)

# %%
search_box = driver.find_element(By.XPATH,'//table[@class = "gstl_50 gsc-input"]/tbody/tr/td/input')
search_box.send_keys('exception handling selenium')
time.sleep(4)

# %%
driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[2]/button').click()
time.sleep(4)

# %%
driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/div[1]/div[6]/div[2]/div/div/div[1]/div[1]/div[1]/div[1]/div/a').click()
time.sleep(4)

# %%
driver.switch_to.window(driver.window_handles[1])

# %%
name = []
for i in driver.find_elements(By.XPATH,'//div[@class="entry-content single-content"]/p/strong'):
    name.append(i.text)
name = name[:-6]

# %%
names = []
for i in name:
    names.append(i.split('.')[1].split(':')[0])

# %%
des = []
for i in driver.find_elements(By.XPATH,'//div[@class="entry-content single-content"]/p'):
    des.append(i.text)

# %%
des = des[:-12]

# %%
len(des)
# Out:
# 41

# %%
desc= []
for i in des:
    try:
        desc.append(i.split(':')[1])
    except:
        desc.append(i)

# %%
len(desc)
# Out:
# 41

# %%
excep = pd.DataFrame({'NameofException':names,'Description':desc})
excep
# Out:
#                       NameofException  \
# 0          ElementNotVisibleException
# 1       ElementNotSelectableException
# 2              NoSuchElementException
# 3                NoSuchFrameException
# 4             NoAlertPresentException
# 5               NoSuchWindowException
# 6      StaleElementReferenceException
# 7            SessionNotFoundException
# 8                    TimeoutException
# 9                  WebDriverException
# 10          ConnectionClosedException
# 11   ElementClickInterceptedException
# 12    ElementNotInteractableException
# 13           ErrorInResponseException
# 14                       ErrorHandler
# 15       ImeActivationFailedException
# 16           ImeNotAvailableException
# 17       InsecureCertificateException
# 18           InvalidArgumentException
# 19       InvalidCookieDomainException
# 20        InvalidCoordinatesException
# 21       InvalidElementStateException
# 22          InvalidSessionIdException
# ...

# %% [markdown]
# # 4. Scrape the details of State-wise GDP of India from statisticstime.com. Url = http://statisticstimes.com/
# ### You have to find following details:
# #### A) Rank
# #### B) State
# #### C) GSDP(18-19)- at current prices
# #### D) GSDP(19-20)- at current prices
# #### E) Share(18-19)
# #### F) GDP(billion)
# Note: - From statisticstimes home page you have to reach to economy page through code

# %%
driver = webdriver.Chrome(r'C:\Users\bhanu\chromedriver.exe')
driver.maximize_window()

url = 'https://statisticstimes.com/'
driver.get(url)

time.sleep(5)

# %%
from selenium.webdriver.common.action_chains import ActionChains

# %%
a = ActionChains(driver)
m = driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/button')
a.move_to_element(m).perform()
time.sleep(3)

# %%
ind = driver.find_element(by = By.LINK_TEXT, value="India")
ind.click()
time.sleep(5)

# %%
driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[2]/ul/li[1]/a').click()

# %%
rank = []
state = []
prev = []
cur = []
share = []
gdp = []

# %%
for i in driver.find_elements(By.XPATH, '/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[1]'):
    rank.append(i.text)

# %%
for i in driver.find_elements(By.XPATH, '/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[2]'):
    state.append(i.text)

# %%
for i in driver.find_elements(By.XPATH, '/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[3]'):
    cur.append(i.text)

# %%
for i in driver.find_elements(By.XPATH, '/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[4]'):
    prev.append(i.text)

# %%
for i in driver.find_elements(By.XPATH, '/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[5]'):
    share.append(i.text)

# %%
for i in driver.find_elements(By.XPATH, '/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[6]'):
    gdp.append(i.text)

# %%
df = pd.DataFrame({'Rank':rank,'State':state, 'GSDP(18-19)- at current prices':prev, 'GSDP(19-20)- at current prices':cur, 'Share(18-19)':share,'GDP($ billion)':gdp})
df
# Out:
#    Rank                      State GSDP(18-19)- at current prices  \
# 0     1                Maharashtra                      2,632,792
# 1     2                 Tamil Nadu                      1,630,208
# 2     3              Uttar Pradesh                      1,584,764
# 3     4                    Gujarat                      1,502,899
# 4     5                  Karnataka                      1,493,127
# 5     6                West Bengal                      1,089,898
# 6     7                  Rajasthan                        942,586
# 7     8             Andhra Pradesh                        862,957
# 8     9                  Telangana                        861,031
# 9    10             Madhya Pradesh                        809,592
# 10   11                     Kerala                        781,653
# 11   12                      Delhi                        774,870
# 12   13                    Haryana                        734,163
# ...

# %% [markdown]
# # 5. Scrape the details of trending repositories on Github.com. Url = https://github.com/
# ### You have to find the following details:
# #### A) Repository title
# #### B) Repository description
# #### C) Contributors count
# #### D) Language used
#
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
driver = webdriver.Chrome(r'C:\Users\bhanu\chromedriver.exe')
driver.maximize_window()

url = 'https://github.com/'
driver.get(url)

time.sleep(5)

# %%
a = ActionChains(driver)
m = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button')
a.move_to_element(m).perform()
time.sleep(3)

# %%
trnd = driver.find_element(by = By.LINK_TEXT, value="Trending")
trnd.click()
time.sleep(5)

# %%
name = []
des = []
ccount = []
lang = []

# %%
for i in driver.find_elements(By.XPATH,'//article/h1/a'):
    name.append(i.text.split('/')[1])

# %%
len(name)
# Out:
# 25

# %%
for i in driver.find_elements(By.XPATH,'//article/p'):
    des.append(i.text)

# %%
len(des)
# Out:
# 25

# %%
df = pd.DataFrame({'Name':name,'Description':des})
df
# Out:
#                          Name  \
# 0              wechat-chatgpt
# 1                 whisper.cpp
# 2                react-router
# 3          ChatGPT-wechat-bot
# 4                        reth
# 5                   wechatbot
# 6                   PyChatGPT
# 7                   surrealdb
# 8    chatgpt-chrome-extension
# 9                       Hippy
# 10                    ChatGPT
# 11         TeachYourselfCS-CN
# 12       stat_rethinking_2023
# 13      clean-code-javascript
# 14            awesome-chatgpt
# 15                uptime-kuma
# 16       javascript-questions
# 17    awesome-chatgpt-prompts
# 18                       lyra
# 19                chatgpt-mac
# 20                    whisper
# 21      javascript-algorithms
# 22             OpenBBTerminal
# 23     free-programming-books
# 24       system-design-primer
#
#                                           Description
# 0                   Use ChatGPT On Wechat via wechaty
# ...

# %% [markdown]
# # 6. Scrape the details of top 100 songs on billiboard.com. Url = https:/www.billboard.com/
# ### You have to find the following details:
# #### A) Song name
# #### B) Artist name
# #### C) Last week rank
# #### D) Peak rank
# #### E) Weeks on board
# #### Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver = webdriver.Chrome(r'C:\Users\bhanu\chromedriver.exe')
driver.maximize_window()

url = 'https:/www.billboard.com/'
driver.get(url)

time.sleep(5)

# %%
driver.find_element(By.XPATH, '/html/body/div[3]/header/div/div[2]/div/div/div[1]/div[1]/button').click()
time.sleep(3)

# %%
driver.find_element(By.XPATH,'/html/body/div[3]/div[8]/div/div/div/ul/li[1]/ul/li[2]/a').click()
time.sleep(3)

# %%
rank = []
song = []
artist = []
lw = []
pp = []
woc = []

# %%
for i in driver.find_elements(By.XPATH, '//div[@class="o-chart-results-list-row-container"]/ul'):
    rank.append(i.get_attribute("data-detail-target"))

# %%
for i in driver.find_elements(By.XPATH, '//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li/h3'):
    song.append(i.text)

# %%
for i in driver.find_elements(By.XPATH, '//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li[1]/span'):
    artist.append(i.text)

# %%
for i in driver.find_elements(By.XPATH, '//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li[4]/span'):
    lw.append(i.text)

# %%
for i in driver.find_elements(By.XPATH, '//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li[5]/span'):
    pp.append(i.text)

# %%
for i in driver.find_elements(By.XPATH, '//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li[6]/span'):
    woc.append(i.text)

# %%
df = pd.DataFrame({'Rank':rank,'SongName':song, 'ArtistName':artist, 'Last week rank':lw, 'Peak rank':pp,'Weeks on board':woc})
df
# Out:
#    Rank                           SongName                  ArtistName  \
# 0     1                          Anti-Hero                Taylor Swift
# 1     2    All I Want For Christmas Is You                Mariah Carey
# 2     3  Rockin' Around The Christmas Tree                  Brenda Lee
# 3     4                             Unholy      Sam Smith & Kim Petras
# 4     5                   Jingle Bell Rock                 Bobby Helms
# ..  ...                                ...                         ...
# 95   96               Someday At Christmas                       Lizzo
# 96   97                     Vigilante Shit                Taylor Swift
# 97   98                          Forget Me               Lewis Capaldi
# 98   99                 Going, Going, Gone                  Luke Combs
# 99  100                           Miss You  Oliver Tree & Robin Schulz
#
#    Last week rank Peak rank Weeks on board
# 0               1         1              6
# ...

# %% [markdown]
# # 7. Scrape the details of Data science recruiters from naukri.com. Url = https://www.naukri.com/
# ### You have to find the following details:
# #### A) Name
# #### B) Designation
# #### C) Company
# #### D) Skills they hire for
# #### E) Location
# #### Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code

# %%
driver = webdriver.Chrome(r'C:\Users\bhanu\chromedriver.exe')
driver.maximize_window()

url = 'https://www.naukri.com/'
driver.get(url)

time.sleep(5)

# %% [markdown]
# This link does ot work as there are only 3 options
# 1. Jobs
# 2. Companies
# 3. Services

# %%
driver = webdriver.Chrome(r'C:\Users\bhanu\chromedriver.exe')
driver.maximize_window()

url = 'https://www.naukri.com/hr-recruiters-consultants'
driver.get(url)

time.sleep(5)

# %%
srch = driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/div/div[1]/div[1]/div[2]/input')
srch.send_keys("Data Science")

# %%
driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/button').click()
time.sleep(5)

# %%
loc = ['Delhi','Bengaluru','Bangalore','Bengaluru / Bangalore','Hyderabad / Secunderabad','Hyderabad','Vadodara / Baroda','Vadodara','Baroda','Chennai','Mumbai','Pune','Ahmedabad','Kolkata','Ernakulam','Kochi','Cochin','Indore','Jaipur','Coimbatore','Chandigarh','Navi' 'Mumbai','Lucknow','Trivandrum','Nagpur','Surat','Bhopal','Mohali','Aurangabad','Visakhapatnam','Bhubaneshwar','Ludhiana','Nasik']

# %%
name = []
title = []
company = []
location = []
skills = []

# %%
for i in range(1,120):
    url = 'https://www.naukri.com/data-science-recruiters-'+str(i)+'?xz=1_0_0&xid=167066073333664400'
    driver.get(url)
    time.sleep(1)
    for j in driver.find_elements(By.XPATH,'//div[@class="vcard"]/p/a/span'):
        name.append(j.text)
    for j in driver.find_elements(By.XPATH,'//div[@class="vcard"]/p/span[@class="ellipsis clr"]'):
        title.append(j.text)
    for j in driver.find_elements(By.XPATH,'//div[@class="vcard"]/p/a[2]'):
        company.append(j.get_attribute('title'))
    x = driver.find_elements(By.XPATH,'//div[@class="vcard"]/p')
    a = []
    for i in x:
        a.append(i.text)
    locs = []
    for i in a:
        locs.append(i.split('\n')[-1])
    for i in locs:
        if i in loc:
            location.append(i)
        else:
            location.append('others')
    for j in driver.find_elements(By.XPATH,'//div[@class="hireSec highlightable"]'):
        skills.append(j.text)

# %%
df = pd.DataFrame({'Name':name,'Title':title, 'Company':company, 'Location':location, 'SkillsHiredfor':skills})
df
# Out:
#                           Name                             Title  \
# 0                 Aakash Harit                        HR Manager
# 1         shravan Kumar Gaddam                 Company Recruiter
# 2     MARSIAN Technologies LLP                        Company HR
# 3                 Anik Agrawal                 Company Recruiter
# 4                 subhas patel                       Founder CEO
# ...                        ...                               ...
# 5940               manoj gupta                   Chief Executive
# 5941            Abhishek Singh            Sr. Talent Acquisition
# 5942                  Vaishali                           TA Lead
# 5943                     Dhara  Talent Acquisition Pan India SAP
# 5944                   Doksiri                      Data Analyst
#
#                                     Company                  Location  \
# 0                      Data Science Network                     Delhi
# ...

# %% [markdown]
# # 8. Scrape the details of Highest selling novels.
# ### Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey- compare/
# #### You have to find the following details:
# #### A) Book name
# #### B) Author name
# #### C) Volumes sold
# #### D) Publisher
# #### E) Genre

# %%
driver = webdriver.Chrome(r'C:\Users\bhanu\chromedriver.exe')
driver.maximize_window()

url = 'https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare'
driver.get(url)

time.sleep(5)

# %%
bname = []
aname = []
volsold = []
pub = []
genre = []

# %%
for i in driver.find_elements(By.XPATH, '//tbody/tr/td[2]'):
    bname.append(i.text)
for i in driver.find_elements(By.XPATH, '//tbody/tr/td[3]'):
    aname.append(i.text)
for i in driver.find_elements(By.XPATH, '//tbody/tr/td[4]'):
    volsold.append(i.text)
for i in driver.find_elements(By.XPATH, '//tbody/tr/td[5]'):
    pub.append(i.text)
for i in driver.find_elements(By.XPATH, '//tbody/tr/td[6]'):
    genre.append(i.text)

# %%
df = pd.DataFrame({'BookName':bname,'AuthorName':aname, 'VolumeSales':volsold, 'Publisher':pub, 'Genre':genre})
df
# Out:
#                                              BookName        AuthorName  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    VolumeSales        Publisher                        Genre
# ...

# %% [markdown]
# # 9. Scrape the details most watched tv series of all time from imdb.com. Url = https://www.imdb.com/list/ls095964455/
# ### You have to find the following details:
# #### A) Name
# #### B) Year span
# #### C) Genre
# #### D) Run time
# #### E) Ratings
# #### F) Votes

# %%
driver = webdriver.Chrome(r'C:\Users\bhanu\chromedriver.exe')
driver.maximize_window()

url = 'https://www.imdb.com/list/ls095964455/'
driver.get(url)

time.sleep(5)

# %%
name = []
year = []
genre = []
rt = []
rat = []
votes = []

# %%
for i in driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/h3/a'):
    name.append(i.text)
for i in driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/h3/span[2]'):
    year.append(i.text)
for i in driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/p/span[@class="genre"]'):
    genre.append(i.text)
for i in driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/p/span[@class="runtime"]'):
    rt.append(i.text)
for i in driver.find_elements(By.XPATH,'//div[@class="ipl-rating-star small"]/span[2]'):
    rat.append(i.text)
for i in driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/p[4]/span[2]'):
    votes.append(i.text)

# %%
df = pd.DataFrame({'Name':name,'Year':year, 'Genre':genre, 'RunTime':rt, 'Ratings':rat,'Votes':votes})
df
# Out:
#                               Name         Year                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds     (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#     RunTime Ratings      Votes
# 0    57 min     9.2  2,091,066
# ...

# %% [markdown]
# # 10. Details of Datasets from UCI machine learning repositories. Url = https://archive.ics.uci.edu/
# ### You have to find the following details:
# #### A) Dataset name
# #### B) Data type
# #### C) Task
# #### D) Attribute type
# #### E) No of instances
# #### F) No of attribute
# #### G) Year
# #### Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
driver = webdriver.Chrome(r'C:\Users\bhanu\chromedriver.exe')
driver.maximize_window()

url = 'https://archive.ics.uci.edu/'
driver.get(url)

time.sleep(5)

# %%
driver.find_element(By.XPATH,'/html/body/table[1]/tbody/tr/td[2]/span[2]/a').click()
time.sleep(4)

# %%
name = []
dtype = []
task = []
atype = []
ins = []
att = []
yr = []

# %%
for i in driver.find_elements(By.XPATH, '//td[@valign="top"]/table[@border="1"]/tbody/tr/td/table/tbody/tr/td[2]/p/b/a'):
    name.append(i.text)
for i in driver.find_elements(By.XPATH, '/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]/p[@class="normal"]'):
    dtype.append(i.text)
for i in driver.find_elements(By.XPATH, '/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]/p[@class="normal"]'):
    task.append(i.text)
for i in driver.find_elements(By.XPATH, '/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]/p[@class="normal"]'):
    atype.append(i.text)
for i in driver.find_elements(By.XPATH, '/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]/p[@class="normal"]'):
    ins.append(i.text)
for i in driver.find_elements(By.XPATH, '/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]/p[@class="normal"]'):
    att.append(i.text)
for i in driver.find_elements(By.XPATH, '/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]/p[@class="normal"]'):
    yr.append(i.text)

# %%
df = pd.DataFrame({'Name':name,'Data Type':dtype, 'Task':task, 'Attribute Type':att, 'Instances':ins,'NumAttributes':att,'Year':yr})
df
# Out:
#                                                   Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data Type                  Task Attribute Type  \
# 0                 Multivariate        Classification              8
# 1                 Multivariate        Classification             14
# 2                 Multivariate        Classification             38
# ...
